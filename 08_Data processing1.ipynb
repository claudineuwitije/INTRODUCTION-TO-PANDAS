# %% [markdown]
# # DATA PROCESSING - Numerical features
#
# - Using describe() method to create a statistical summary of numerical features
# - Arithmethical operations on pandas objects
# - Finding the minimum and Maximum values
# - Finding the n-smallest and n-largest values
# - calculate statistics: e.g mean, median,variance, and standard deviation

# %%
import pandas as pd

# %%
df1=pd.read_csv('INTRODUCTION-TO-PANDAS/Dataset/IMDB-Movie-Data.csv')
df1
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df1.shape
# Out:
# (1000, 12)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df1.describe() # "Describe" generate a descriptive statistics  that summarize central tendency for each numerical feature
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df1.Rank.describe() # generating a descriptive statistics for a specific variable. In this case:"Rank"
# Out:
# count    1000.000000
# mean      500.500000
# std       288.819436
# min         1.000000
# 25%       250.750000
# 50%       500.500000
# 75%       750.250000
# max      1000.000000
# Name: Rank, dtype: float64

# %% [markdown]
# ## Q1: Create two seperate columns (Hours, Minute) from Runtime column

# %%
df1['Hour']=df1['Runtime (Minutes)']//60 # Calculating hours from minutes input data

# %%
df1['Minute']=df1['Runtime (Minutes)']%60 # calculating the remainder (minutes after deducing the hours)

# %%
df1
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df1.Hour*60+df1.Minute
# Out:
# 0      121
# 1      124
# 2      117
# 3      108
# 4      123
#       ...
# 995    111
# 996     94
# 997     98
# 998     93
# 999     87
# Length: 1000, dtype: int64

# %%
df1
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ## Q2:  How long is the longest and the shortest movie

# %%
df1['Runtime (Minutes)'].max()
# Out:
# 191

# %%
df1['Runtime (Minutes)'].min()
# Out:
# 66

# %% [markdown]
# ## Q3:  What is the name of the longest movie?

# %%
df1['Runtime (Minutes)'].idxmax() # accessing the index of the longest movies
# Out:
# 828

# %%
df1.loc[df1['Runtime (Minutes)'].idxmax()] # accessing the variable colomun
# Out:
# Rank                                                                829
# Title                                                        Grindhouse
# Genre                                            Action,Horror,Thriller
# Description           Quentin Tarantino and Robert Rodriguez's homag...
# Director                                               Robert Rodriguez
# Actors                Kurt Russell, Rose McGowan, Danny Trejo, Zoë Bell
# Year                                                               2007
# Runtime (Minutes)                                                   191
# Rating                                                              7.6
# Votes                                                            160350
# Revenue (Millions)                                                25.03
# Metascore                                                           NaN
# Hour                                                                  3
# ...

# %%
df1.loc[df1['Runtime (Minutes)'].idxmax()].Title
# Out:
# 'Grindhouse'

# %%
df1.loc[828,'Title']
# Out:
# 'Grindhouse'

# %% [markdown]
# ## Q4:  Find the first five shotest movie?

# %%
df1['Runtime (Minutes)'].nsmallest() # acccess more thatn one item
# Out:
# 793    66
# 42     73
# 819    73
# 711    80
# 949    80
# Name: Runtime (Minutes), dtype: int64

# %%
shotest_05Movies=df1.loc[df1['Runtime (Minutes)'].nsmallest()]
shotest_05Movies
# Out:
#     Rank              Title                    Genre  \
# 66    67       Patriots Day   Drama,History,Thriller
# 73    74  Collateral Beauty            Drama,Romance
# 73    74  Collateral Beauty            Drama,Romance
# 80    81          Inception  Action,Adventure,Sci-Fi
# 80    81          Inception  Action,Adventure,Sci-Fi
#
#                                           Description           Director  \
# 66  The story of the 2013 Boston Marathon bombing ...         Peter Berg
# 73  Retreating from life after a tragedy, a man qu...      David Frankel
# 73  Retreating from life after a tragedy, a man qu...      David Frankel
# 80  A thief, who steals corporate secrets through ...  Christopher Nolan
# 80  A thief, who steals corporate secrets through ...  Christopher Nolan
#
#                                                Actors  Year  \
# 66  Mark Wahlberg, Michelle Monaghan, J.K. Simmons...  2016
# 73  Will Smith, Edward Norton, Kate Winslet, Micha...  2016
# ...

# %% [markdown]
# ## Q5:  Find  the longest movie in 2016

# %%
df1.loc[df1.Year==2016] # Filtering 2016 movies
# Out:
#      Rank                           Title                     Genre  \
# 2       3                           Split           Horror,Thriller
# 3       4                            Sing   Animation,Comedy,Family
# 4       5                   Suicide Squad  Action,Adventure,Fantasy
# 5       6                  The Great Wall  Action,Adventure,Fantasy
# 6       7                      La La Land        Comedy,Drama,Music
# ..    ...                             ...                       ...
# 975   976      My Big Fat Greek Wedding 2     Comedy,Family,Romance
# 977   978                   Amateur Night                    Comedy
# 978   979  It's Only the End of the World                     Drama
# 980   981            Miracles from Heaven    Biography,Drama,Family
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# ...

# %%
df1.loc[df1.Year==2016]['Runtime (Minutes)'].max()
# Out:
# 163

# %%
df1.loc[df1.Year==2016]['Runtime (Minutes)'].idxmax()
# Out:
# 225

# %%
df1.loc[df1.loc[df1.Year==2016]['Runtime (Minutes)'].idxmax()].Title
# Out:
# 'American Honey'

# %% [markdown]
# ## Q6:  Find  the longest movie in 2015 and 2016

# %%
df1.loc[df1['Year'].isin([2015, 2016])] # Using isin to filter rows based on multiple values
# Out:
#      Rank                           Title                     Genre  \
# 2       3                           Split           Horror,Thriller
# 3       4                            Sing   Animation,Comedy,Family
# 4       5                   Suicide Squad  Action,Adventure,Fantasy
# 5       6                  The Great Wall  Action,Adventure,Fantasy
# 6       7                      La La Land        Comedy,Drama,Music
# ..    ...                             ...                       ...
# 978   979  It's Only the End of the World                     Drama
# 980   981            Miracles from Heaven    Biography,Drama,Family
# 984   985                             Max          Adventure,Family
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# ...

# %%
df1.loc[df1.loc[df1['Year'].isin([2015, 2016])]['Runtime (Minutes)'].idxmax()].Title
# Out:
# 'The Hateful Eight'

# %% [markdown]
# ## Q7:  What is the average, median, variance of rating in this dataset

# %%
df1.Rating.mean()
# Out:
# 6.723199999999999

# %%
df1.Rating.median()
# Out:
# 6.8

# %%
df1.Rating.var()
# Out:
# 0.8938355955955963

# %% [markdown]
# ## Q8:  Check if there is a relationship between rating and votes

# %%
df1.Votes.cov(df1.Rating) # Calculating the variance
# Out:
# 91289.78967367364

# %%
df1.Rating.cov(df1.Votes)
# Out:
# 91289.78967367364

# %%
df1.Votes.corr(df1.Rating) # Calculating the correlation
# Out:
# 0.5115373197657554

# %%
numeric_df1 = df1.select_dtypes(include=[int, float])
numeric_df1
# Out:
#      Rank  Year  Runtime (Minutes)  Rating   Votes  Revenue (Millions)  \
# 0       1  2014                121     8.1  757074              333.13
# 1       2  2012                124     7.0  485820              126.46
# 2       3  2016                117     7.3  157606              138.12
# 3       4  2016                108     7.2   60545              270.32
# 4       5  2016                123     6.2  393727              325.02
# ..    ...   ...                ...     ...     ...                 ...
# 995   996  2015                111     6.2   27585                 NaN
# 996   997  2007                 94     5.5   73152               17.54
# 997   998  2008                 98     6.2   70699               58.01
# 998   999  2014                 93     5.6    4881                 NaN
# 999  1000  2016                 87     5.3   12435               19.64
#
#      Metascore  Hour  Minute
# 0         76.0     2       1
# 1         65.0     2       4
# ...

# %%
numeric_df1.corr()
# Out:
#                         Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank                1.000000 -0.261605          -0.221739 -0.219555 -0.283876
# Year               -0.261605  1.000000          -0.164900 -0.211219 -0.411904
# Runtime (Minutes)  -0.221739 -0.164900           1.000000  0.392214  0.407062
# Rating             -0.219555 -0.211219           0.392214  1.000000  0.511537
# Votes              -0.283876 -0.411904           0.407062  0.511537  1.000000
# Revenue (Millions) -0.271592 -0.126790           0.267953  0.217654  0.639661
# Metascore          -0.191869 -0.079305           0.211978  0.631897  0.325684
# Hour               -0.185494 -0.107942           0.813791  0.307048  0.332015
# Minute              0.064922 -0.001641          -0.254934 -0.079803 -0.105025
#
#                     Revenue (Millions)  Metascore      Hour    Minute
# Rank                         -0.271592  -0.191869 -0.185494  0.064922
# ...
