# %% [markdown]
# # DATA PROCESSING - Date & Time
#
# - Convert strings to dataTime format
# - Attributes of timestamp object
# - Creating a datetime format from multiple columns
# - Usinf DateTime data to filter DataFrame
# - Using Time Date object in DateTime data processing

# %%
import pandas as pd

# %%
df1=pd.read_csv('INTRODUCTION-TO-PANDAS/Dataset/uforeports.csv')
df1.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df1.shape
# Out:
# (18241, 5)

# %%
df1.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18215 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  object
# dtypes: object(5)
# memory usage: 712.7+ KB

# %%
df1.loc[0,"Time"] # verifying the row one and column "Time"
# Out:
# '6/1/1930 22:00'

# %%
df1.Time=pd.to_datetime(df1.Time) # Converting time into date time type
df1.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
df1.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time               datetime64[ns]
# dtype: object

# %%
df1.loc[0,"Time"] # verifying time column object has been converted into DateTime
# Out:
# Timestamp('1930-06-01 22:00:00')

# %%
df1.loc[0,"Time"].year # accessing the year
# Out:
# 1930

# %%
df1.loc[0,"Time"].month
# Out:
# 6

# %%
df1.loc[0,"Time"].hour
# Out:
# 22

# %%
df1.loc[0,"Time"].day_name()
# Out:
# 'Sunday'

# %%
df1.loc[0,"Time"].month_name()
# Out:
# 'June'

# %%
df1['Year']=df1.Time.dt.year

# %%
df1['Month']=df1.Time.dt.month

# %%
df1['Day']=df1.Time.dt.day

# %%
df1.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  Year  Month  Day
# 0 1930-06-01 22:00:00  1930      6    1
# 1 1930-06-30 20:00:00  1930      6   30
# 2 1931-02-15 14:00:00  1931      2   15
# 3 1931-06-01 13:00:00  1931      6    1
# 4 1933-04-18 19:00:00  1933      4   18

# %%
df1.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time               datetime64[ns]
# Year                        int32
# Month                       int32
# Day                         int32
# dtype: object

# %%
pd.to_datetime(df1[['Year','Month','Day']]) # Converting Year, Month, Day into one datetime
# Out:
# 0       1930-06-01
# 1       1930-06-30
# 2       1931-02-15
# 3       1931-06-01
# 4       1933-04-18
#            ...
# 18236   2000-12-31
# 18237   2000-12-31
# 18238   2000-12-31
# 18239   2000-12-31
# 18240   2000-12-31
# Length: 18241, dtype: datetime64[ns]

# %%
df1['new_Date']= pd.to_datetime(df1[['Year','Month','Day']])
df1.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  Year  Month  Day   new_Date
# 0 1930-06-01 22:00:00  1930      6    1 1930-06-01
# 1 1930-06-30 20:00:00  1930      6   30 1930-06-30
# 2 1931-02-15 14:00:00  1931      2   15 1931-02-15
# 3 1931-06-01 13:00:00  1931      6    1 1931-06-01
# 4 1933-04-18 19:00:00  1933      4   18 1933-04-18

# %%
df1.Time.dt.year==1985 # filtering data frame based on the specific year
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18236    False
# 18237    False
# 18238    False
# 18239    False
# 18240    False
# Name: Time, Length: 18241, dtype: bool

# %%
df1.loc[df1.Time.dt.year==1985] # filtering data frame based on the specific year
# Out:
#                 City Colors Reported Shape Reported State                Time  \
# 5171           Holly             NaN          OTHER    MI 1985-01-01 01:00:00
# 5172           Largo             RED          OTHER    FL 1985-01-01 21:00:00
# 5173  Virginia Beach             RED            NaN    VA 1985-01-01 22:00:00
# 5174   Caribbean Sea             NaN          OTHER    FL 1985-01-01 23:00:00
# 5175          Wampum             NaN         CIRCLE    PA 1985-01-15 03:00:00
# ...              ...             ...            ...   ...                 ...
# 5377        Savannah  RED GREEN BLUE       TRIANGLE    GA 1985-12-15 23:00:00
# 5378         Buckner             NaN       TRIANGLE    MO 1985-12-16 18:00:00
# 5379         Vallejo             NaN       TRIANGLE    CA 1985-12-16 19:00:00
# 5380   West Yarmouth             NaN        DIAMOND    MA 1985-12-20 22:00:00
# 5381      Ridgefield             NaN         CIRCLE    CT 1985-12-25 22:00:00
#
# ...

# %%
df1.set_index('Time',inplace=True) # setting a column as a new index to facilitate the manipulation of the data

# %%
df1.set_index('Time')

# %%
df1.head() # here time ins not part of the data frame as it has been converted into index
# Out:
#                                      City Colors Reported Shape Reported  \
# Time
# 1930-06-01 22:00:00                Ithaca             NaN       TRIANGLE
# 1930-06-30 20:00:00           Willingboro             NaN          OTHER
# 1931-02-15 14:00:00               Holyoke             NaN           OVAL
# 1931-06-01 13:00:00               Abilene             NaN           DISK
# 1933-04-18 19:00:00  New York Worlds Fair             NaN          LIGHT
#
#                     State  Year  Month  Day   new_Date
# Time
# 1930-06-01 22:00:00    NY  1930      6    1 1930-06-01
# 1930-06-30 20:00:00    NJ  1930      6   30 1930-06-30
# 1931-02-15 14:00:00    CO  1931      2   15 1931-02-15
# 1931-06-01 13:00:00    KS  1931      6    1 1931-06-01
# 1933-04-18 19:00:00    NY  1933      4   18 1933-04-18

# %%
df1.loc['1985'] # Accessing all values in the year 1985
# Out:
#                                City Colors Reported Shape Reported State  \
# Time
# 1985-01-01 01:00:00           Holly             NaN          OTHER    MI
# 1985-01-01 21:00:00           Largo             RED          OTHER    FL
# 1985-01-01 22:00:00  Virginia Beach             RED            NaN    VA
# 1985-01-01 23:00:00   Caribbean Sea             NaN          OTHER    FL
# 1985-01-15 03:00:00          Wampum             NaN         CIRCLE    PA
# ...                             ...             ...            ...   ...
# 1985-12-15 23:00:00        Savannah  RED GREEN BLUE       TRIANGLE    GA
# 1985-12-16 18:00:00         Buckner             NaN       TRIANGLE    MO
# 1985-12-16 19:00:00         Vallejo             NaN       TRIANGLE    CA
# 1985-12-20 22:00:00   West Yarmouth             NaN        DIAMOND    MA
# 1985-12-25 22:00:00      Ridgefield             NaN         CIRCLE    CT
#
#                      Year  Month  Day   new_Date
# Time
# ...

# %%
df1.loc['1990-10'] # Accessing all values of the year 1990, in october
# Out:
#                                       City Colors Reported Shape Reported  \
# Time
# 1990-10-01 17:00:00                Pateros             NaN           OVAL
# 1990-10-01 20:00:00              San Pedro             NaN          LIGHT
# 1990-10-01 22:15:00              Jamestown             NaN          LIGHT
# 1990-10-05 22:00:00                 Fresno             NaN        VARIOUS
# 1990-10-10 21:00:00                Ashburn             NaN       TRIANGLE
# 1990-10-13 16:00:00             Rising Sun             NaN         SPHERE
# 1990-10-14 21:00:00             Reidsville           GREEN           OVAL
# 1990-10-15 00:15:00                Endwell             NaN      FORMATION
# 1990-10-15 03:00:00          North Windham             NaN       FIREBALL
# 1990-10-15 17:00:00              Las Vegas             NaN          LIGHT
# 1990-10-15 20:00:00             Prineville             NaN          LIGHT
# 1990-10-15 21:00:00                  Omaha             NaN          CIGAR
# ...

# %%
df1.loc['1990':"1993"]
# Out:
#                                  City Colors Reported Shape Reported State  \
# Time
# 1990-01-01 00:00:00       Minneapolis             NaN            NaN    MN
# 1990-01-01 23:00:00           no data             NaN            NaN    NV
# 1990-01-03 20:00:00       Barkhamsted             NaN            NaN    CT
# 1990-01-06 22:00:00       New Orleans             NaN           DISK    LA
# 1990-01-07 09:00:00            Sutton             NaN        VARIOUS    AK
# ...                               ...             ...            ...   ...
# 1993-12-19 18:00:00           Ottumwa             NaN      FORMATION    IA
# 1993-12-20 19:00:00      Williamsport             NaN       TRIANGLE    PA
# 1993-12-23 12:00:00  Castaic Junction             NaN           OVAL    CA
# 1993-12-24 21:00:00        Bellflower             NaN          LIGHT    MO
# 1993-12-28 01:00:00            Topton             NaN            NaN    MS
#
#                      Year  Month  Day   new_Date
# Time
# ...

# %%
df2=pd.read_csv('INTRODUCTION-TO-PANDAS/Dataset/employees.csv')
df2.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df2.dtypes
# Out:
# First Name            object
# Gender                object
# Start Date            object
# Last Login Time       object
# Salary                 int64
# Bonus %              float64
# Senior Management     object
# Team                  object
# dtype: object

# %%
df2.loc[0,"Start Date"]
# Out:
# '8/6/1993'

# %%
df2['Start Date']=pd.to_datetime(df2['Start Date'])

# %%
df2.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
today=pd.Timestamp.today()

# %%
today - df2['Start Date']
# Out:
# 0     11301 days 07:51:21.094303
# 1     10333 days 07:51:21.094303
# 2     11406 days 07:51:21.094303
# 3      7073 days 07:51:21.094303
# 4      9669 days 07:51:21.094303
#                  ...
# 995    3522 days 07:51:21.094303
# 996   14776 days 07:51:21.094303
# 997    4074 days 07:51:21.094303
# 998    4104 days 07:51:21.094303
# 999    4444 days 07:51:21.094303
# Name: Start Date, Length: 1000, dtype: timedelta64[ns]

# %%
df2['Interval']=today - df2['Start Date'] # calculating the number of day that empleyer has been working in company

# %%
df2.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
#
#   Senior Management             Team                   Interval
# 0              True        Marketing 11301 days 07:51:21.094303
# 1              True              NaN 10333 days 07:51:21.094303
# 2             False          Finance 11406 days 07:51:21.094303
# 3              True          Finance  7073 days 07:51:21.094303
# 4              True  Client Services  9669 days 07:51:21.094303

# %%
df2.Interval.dt.days # Extacting the number of days that an employees has been working for a company
# Out:
# 0      11301
# 1      10333
# 2      11406
# 3       7073
# 4       9669
#        ...
# 995     3522
# 996    14776
# 997     4074
# 998     4104
# 999     4444
# Name: Interval, Length: 1000, dtype: int64
